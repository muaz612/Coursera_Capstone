# %% [markdown]
#
# <h1 align="center"><font size="5">Predition of the Severity of an Accident</font></h1>

# %% [markdown]
# This capstone project is to predict the severity of an accident, and warn about the possibility of getting into a car accident given the weather and the road conditions.

# %%
import pandas as pd
import numpy as np

print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
